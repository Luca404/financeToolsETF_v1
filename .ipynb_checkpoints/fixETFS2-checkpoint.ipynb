# %%
import pandas as pd

# %%
dataMilano = pd.read_csv( "ETF_Milano_1.csv" )
dataMilano
# Out:
#               ISIN                                      Name       Symbol  \
# 0     DE0002635265             ISHARES PFANDBRIEFE UCITS ETF  EXHE:MILANO
# 1     DE0002635299   ISHARES STX EUROPE SEL DIV 30 UCITS ETF  EXSH:MILANO
# 2     DE0002635307  ISHARES STOXX EUROPE600EUR DIS UCITS ETF  EXSA:MILANO
# 3     DE0005933931                ISHARES CORE DAX UCITS ETF  EXS1:MILANO
# 4     DE000A0D8Q07              ISHARES EURO STOXX UCITS ETF  EXSI:MILANO
# ...            ...                                       ...          ...
# 1475  IE000APK27S2   iShares Glb Agg Bond ESG UCITS ETF HD A  AEGE:MILANO
# 1476  IE000MELAE65   iShares MSCI World Energy ESG UCITS ETF  WENE:MILANO
# 1477  IE00BJ5JNZ06   iShares MSCI Wrd Health C ESG UCITS ETF  WHCS:MILANO
# 1478  IE00BJ5JNY98  iShares MSCI Wrd Info Tech ESG UCITS ETF  WITS:MILANO
# 1479  IE00BJ5JP766   iShares MSCI Wrd Material ESG UCITS ETF  WMTS:MILANO
#
#      Type    TER     Dividendi                                      info  \
# ...

# %%
dataMilano[["Area","Sector","Maturities"]] = dataMilano["Area"].str.split(",",2,expand=True)
# Out:
# /tmp/ipykernel_8394/4218513951.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   dataMilano[["Area","Sector","Maturities"]] = dataMilano["Area"].str.split(",",2,expand=True)

# %%
dataMilano = dataMilano.drop('info', axis=1)

# %%
dataMilano
# Out:
#               ISIN                                      Name       Symbol  \
# 0     DE0002635265             ISHARES PFANDBRIEFE UCITS ETF  EXHE:MILANO
# 1     DE0002635299   ISHARES STX EUROPE SEL DIV 30 UCITS ETF  EXSH:MILANO
# 2     DE0002635307  ISHARES STOXX EUROPE600EUR DIS UCITS ETF  EXSA:MILANO
# 3     DE0005933931                ISHARES CORE DAX UCITS ETF  EXS1:MILANO
# 4     DE000A0D8Q07              ISHARES EURO STOXX UCITS ETF  EXSI:MILANO
# ...            ...                                       ...          ...
# 1475  IE000APK27S2   iShares Glb Agg Bond ESG UCITS ETF HD A  AEGE:MILANO
# 1476  IE000MELAE65   iShares MSCI World Energy ESG UCITS ETF  WENE:MILANO
# 1477  IE00BJ5JNZ06   iShares MSCI Wrd Health C ESG UCITS ETF  WHCS:MILANO
# 1478  IE00BJ5JNY98  iShares MSCI Wrd Info Tech ESG UCITS ETF  WITS:MILANO
# 1479  IE00BJ5JP766   iShares MSCI Wrd Material ESG UCITS ETF  WMTS:MILANO
#
#      Type    TER     Dividendi Trading Currency BenchmarkType     Area  \
# ...

# %%
dataMilano.to_csv("ETF_Milano_1.csv")

# %%
dataXetra = pd.read_csv( "ETF_Xetra.csv" )

# %%
dataXetra["Symbol"] = dataXetra["Symbol"] + ":XETRA"

# %%
dataXetra
# Out:
#               ISIN                                               Name  \
# 0     IE00B5ZR2157                PIMCO Euro Short Maturity UCITS ETF
# 1     LU0599612842  Ossiam Europe ESG Machine Learning UCITS ETF -...
# 2     IE00BF8HV717                       PIMCO Covered Bond UCITS ETF
# 3     IE00BP9F2J32   PIMCO Euro Low Duration Corporate Bond UCITS ETF
# 4     IE00BVZ6SP04        PIMCO Euro Short Maturity UCITS ETF EUR ACC
# ...            ...                                                ...
# 2517  JE00BPRDNL86        CoinShares Physical Top10 Crypto Market ETP
# 2518  JE00BPRDNM93    CoinShares Physical Smart Contract Platform ETP
# 2519  CH1135202179                      21Shares Crypto Basket 10 ETP
# 2520  DE000A3G3ZL3        ETC Group MSCI Digital Assets Select 20 ETP
# 2521  DE000A3G3ZL3        ETC Group MSCI Digital Assets Select 20 ETP
#
#                 Symbol        Type    TER     Dividendi Trading Currency
# ...

# %%
etfList = pd.concat([dataMilano, dataXetra], ignore_index=True)

# %%
etfList
# Out:
#               ISIN                                             Name  \
# 0     DE0002635265                    ISHARES PFANDBRIEFE UCITS ETF
# 1     DE0002635299          ISHARES STX EUROPE SEL DIV 30 UCITS ETF
# 2     DE0002635307         ISHARES STOXX EUROPE600EUR DIS UCITS ETF
# 3     DE0005933931                       ISHARES CORE DAX UCITS ETF
# 4     DE000A0D8Q07                     ISHARES EURO STOXX UCITS ETF
# ...            ...                                              ...
# 3997  JE00BPRDNL86      CoinShares Physical Top10 Crypto Market ETP
# 3998  JE00BPRDNM93  CoinShares Physical Smart Contract Platform ETP
# 3999  CH1135202179                    21Shares Crypto Basket 10 ETP
# 4000  DE000A3G3ZL3      ETC Group MSCI Digital Assets Select 20 ETP
# 4001  DE000A3G3ZL3      ETC Group MSCI Digital Assets Select 20 ETP
#
#                 Symbol Type    TER     Dividendi Trading Currency
# 0          EXHE:MILANO  ETF  0,10%  Distributing              EUR
# ...

# %%
etfList.to_json( "etfList.json" )
